# %%
import pandas as pd

# %%
df = pd.read_csv('Dataset/dataset.csv')

# %%
streaming = df['']
# Out:
#                       artists                  track_name  popularity  \
# 0                 Gen Hoshino                      Comedy          73
# 1                Ben Woodward            Ghost - Acoustic          55
# 2      Ingrid Michaelson;ZAYN              To Begin Again          57
# 3                Kina Grannis  Can't Help Falling In Love          71
# 4            Chord Overstreet                     Hold On          82
# ...                       ...                         ...         ...
# 81338           Rainy Lullaby         Sleep My Little Boy          21
# 81339           Rainy Lullaby            Water Into Light          22
# 81340           Cesária Evora              Miss Perfumado          22
# 81341        Michael W. Smith                     Friends          41
# 81342           Cesária Evora                   Barbincor          22
#
#        duration_ms  danceability  energy  key  loudness  mode  speechiness  \
# ...
